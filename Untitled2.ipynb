# %%
import torch, torchvision
print("Torch:", torch.__version__)
print("TorchVision:", torchvision.__version__)
print("CUDA available:", torch.cuda.is_available())  # Should be False


import torch
import gymnasium as gym
import stable_baselines3 as sb3


print("Torch version:", torch.__version__)
print("Gymnasium version:", gym.__version__)
print("SB3 version:", sb3.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.9.1+cpu
# TorchVision: 0.24.1+cpu
# CUDA available: False
# Torch version: 2.9.1+cpu
# Gymnasium version: 1.1.1
# SB3 version: 2.6.0
# CUDA available: False

# %%
! pip install gymnasium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached gymnasium-1.2.2-py3-none-any.whl (952 kB)
# ...

# %%
import sys
import os

import gymnasium as gym
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

from env.hospital_env import HospitalEnv  # your custom environment

# %%
env = HospitalEnv()       # create environment
obs, info = env.reset()   # reset it to get initial observation
print("Initial observation:", obs)

# Test one random action
action = env.action_space.sample()
obs, reward, terminated, truncated, info = env.step(action)
done = terminated or truncated
print("Next observation:", obs, "Reward:", reward, "Done:", done)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 env = HospitalEnv()       # create environment
# ----> 2 obs, info = env.reset()   # reset it to get initial observation
#       3 print("Initial observation:", obs)
#       5 # Test one random action
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
env = HospitalEnv()

result = env.reset()
print("RESET RETURNED:", result)
print("TYPE:", type(result))
# Out:
# RESET RETURNED: None
# TYPE: <class 'NoneType'>

# %%
import inspect
import env.hospital_env as he

print(he.__file__)

# %%
import importlib
from env import hospital_env

importlib.reload(hospital_env)
from env.hospital_env import HospitalEnv

# %%
env = HospitalEnv()
obs, info = env.reset()
print("OBS:", obs)
print("INFO:", info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 env = HospitalEnv()
# ----> 2 obs, info = env.reset()
#       3 print("OBS:", obs)
#       4 print("INFO:", info)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
env = HospitalEnv()
result = env.reset()
print(result)
print(type(result))
# Out:
# None
# <class 'NoneType'>

# %%
env = HospitalEnv()
obs, info = env.reset()
print("OBS:", obs)
print("INFO:", info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 env = HospitalEnv()
# ----> 2 obs, info = env.reset()
#       3 print("OBS:", obs)
#       4 print("INFO:", info)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# Import the environment class
# from hospital_env import HospitalEnv  # if saved in a separate file
from hospital_env import HospitalEnv
env = HospitalEnv()  # create environment
obs, info = env.reset()

print("Initial observation:", obs)

# Run for 10 steps
for step in range(10):
    # Choose a random action (0=Red, 1=Yellow, 2=Green)
    action = env.action_space.sample()

    obs, reward, done, info = env.step(action)

    print(f"\nStep {step+1}")
    print("Action taken:", action)
    print("Observation:", obs)
    print("Reward:", reward)
    print("Doctor timers:", env.doctor_timers)
    print("Red queue length:", len(env.red_queue))
    print("Yellow queue length:", len(env.yellow_queue))
    print("Green queue length:", len(env.green_queue))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Import the environment class
#       2 # from hospital_env import HospitalEnv  # if saved in a separate file
# ----> 3 from hospital_env import HospitalEnv
#       4 env = HospitalEnv()  # create environment
#       5 obs, info = env.reset()
#
# ModuleNotFoundError: No module named 'hospital_env'
