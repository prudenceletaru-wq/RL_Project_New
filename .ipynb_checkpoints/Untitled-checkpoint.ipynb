# %%
import gym
import numpy as np
from gym import spaces

class HospitalEnv(gym.Env):
    """
    Simple queue environment with triage-based service times.
    Service times follow lognormal distributions whose means are:
    Red = 25 mins, Yellow = 15 mins, Green = 10 mins.
    """

    def __init__(self):
        super(HospitalEnv, self).__init__()

        # Observation: number of patients in each category
        self.observation_space = spaces.Box(low=0, high=100, shape=(3,), dtype=np.int32)

        # Action: choose which category to serve (0 = Red, 1 = Yellow, 2 = Green)
        self.action_space = spaces.Discrete(3)

        # Patient queues (list of waiting times)
        self.red_queue = []
        self.yellow_queue = []
        self.green_queue = []

        # --------------------------
        # SERVICE TIME DISTRIBUTIONS
        # --------------------------
        # Means: Red = 25, Yellow = 15, Green = 10
        # We assume reasonable variance and convert to lognormal parameters.

        def lognormal_params(mean, std):
            """Convert actual mean/std to log-space μ and σ."""
            variance = std ** 2
            mu = np.log(mean**2 / np.sqrt(variance + mean**2))
            sigma = np.sqrt(np.log(1 + variance / (mean**2)))
            return mu, sigma

        # Approximated standard deviations for realistic variability
        red_std = 8
        yellow_std = 5
        green_std = 3

        self.red_mu, self.red_sigma = lognormal_params(25, red_std)
        self.yellow_mu, self.yellow_sigma = lognormal_params(15, yellow_std)
        self.green_mu, self.green_sigma = lognormal_params(10, green_std)

        # Clock
        self.time = 0


    def reset(self):
        self.red_queue = []
        self.yellow_queue = []
        self.green_queue = []
        self.time = 0
        return self._get_obs()


    def _get_obs(self):
        """Observation = queue sizes."""
        return np.array([
            len(self.red_queue),
            len(self.yellow_queue),
            len(self.green_queue)
        ], dtype=np.int32)


    # -----------------------
    # SAMPLING SERVICE TIME
    # -----------------------
    def sample_service_time(self, category):
        if category == 0:  # Red
            return np.random.lognormal(self.red_mu, self.red_sigma)
        elif category == 1:  # Yellow
            return np.random.lognormal(self.yellow_mu, self.yellow_sigma)
        else:  # Green
            return np.random.lognormal(self.green_mu, self.green_sigma)


    def step(self, action):
        # If queue is empty, no service happens
        if action == 0 and len(self.red_queue) == 0:
            service_time = 1
        elif action == 1 and len(self.yellow_queue) == 0:
            service_time = 1
        elif action == 2 and len(self.green_queue) == 0:
            service_time = 1
        else:
            # Sample service time based on category
            service_time = self.sample_service_time(action)

            # Remove one patient from selected queue
            if action == 0:
                self.red_queue.pop(0)
            elif action == 1:
                self.yellow_queue.pop(0)
            else:
                self.green_queue.pop(0)

        # Advance clock
        self.time += service_time

        # Waiting times accumulate
        for q in [self.red_queue, self.yellow_queue, self.green_queue]:
            for i in range(len(q)):
                q[i] += service_time

        # Reward: negative total waiting time
        reward = -(sum(self.red_queue) + sum(self.yellow_queue) + sum(self.green_queue))

        done = False  # Episodic logic optional
        return self._get_obs(), reward, done, {}

# %%
! pip install torch torchvision torchaudio
! pip install stable-baselines3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (2.9.1)
# Requirement already satisfied: torchvision in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (0.24.1)
# Requirement already satisfied: torchaudio in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: numpy in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (2.7.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from stable-baselines3) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from stable-baselines3) (2.2.6)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from stable-baselines3) (2.9.1)
# Requirement already satisfied: cloudpickle in c:\anaconda3\lib\site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in c:\anaconda3\lib\site-packages (from stable-baselines3) (3.8.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=8 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2023.3)

# %%
# !pip install gym
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/721.7 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/721.7 kB ? eta -:--:--
#      ---------------------------------------- 721.7/721.7 kB 1.0 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gym) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\anaconda3\lib\site-packages (from gym) (2.2.1)
# Collecting gym_notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827740 sha256=59825bfd204826cd93c651810a06eed8ddeb9825fb71c358165940fd237ab8a5
#   Stored in directory: c:\users\prudence letaru\appdata\local\pip\cache\wheels\95\51\6c\9bb05ebbe7c5cb8171dfaa3611f32622ca4658d53f31c79077
# Successfully built gym
# Installing collected packages: gym_notices, gym
#
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    -------------------- ------------------- 1/2 [gym]
#    ---------------------------------------- 2/2 [gym]
#
# Successfully installed gym-0.26.2 gym_notices-0.1.0

# %%
! pip install gymnasium[all]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   error: subprocess-exited-with-error
#
#   Building wheel for box2d-py (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [29 lines of output]
#   C:\Users\Prudence Letaru\AppData\Local\Temp\pip-build-env-ab3l0i5b\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'test_suite'
#     warnings.warn(msg)
#   C:\Users\Prudence Letaru\AppData\Local\Temp\pip-build-env-ab3l0i5b\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: zlib/libpng License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   Using setuptools (version 80.9.0).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-312\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-312\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-312\Box2D
#   creating build\lib.win-amd64-cpython-312\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-312\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# error: failed-wheel-build-for-install
#
# Failed to build installable wheels for some pyproject.toml based projects
#
# box2d-py
# Requirement already satisfied: gymnasium[all] in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\anaconda3\lib\site-packages (from gymnasium[all]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (0.11.2)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pygame>=2.1.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (2.6.1)
# Collecting swig==4.* (from gymnasium[all])
#   Using cached swig-4.4.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Using cached mujoco-3.3.7-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: imageio>=2.14.1 in c:\anaconda3\lib\site-packages (from gymnasium[all]) (2.33.1)
# Requirement already satisfied: packaging>=23.0 in c:\anaconda3\lib\site-packages (from gymnasium[all]) (23.2)
# Collecting jax>=0.4.16 (from gymnasium[all])
#   Using cached jax-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib>=0.4.16 (from gymnasium[all])
#   Using cached jaxlib-0.8.1-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# Collecting flax>=0.5.0 (from gymnasium[all])
#   Using cached flax-0.12.1-py3-none-any.whl.metadata (11 kB)
# Collecting array-api-compat>=1.11.0 (from gymnasium[all])
#   Using cached array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: torch>=1.13.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (2.9.1)
# Requirement already satisfied: opencv-python>=3.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from gymnasium[all]) (4.12.0.88)
# Requirement already satisfied: matplotlib>=3.0 in c:\anaconda3\lib\site-packages (from gymnasium[all]) (3.8.4)
# Collecting moviepy>=1.0.0 (from gymnasium[all])
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: msgpack in c:\anaconda3\lib\site-packages (from flax>=0.5.0->gymnasium[all]) (1.0.3)
# Collecting optax (from flax>=0.5.0->gymnasium[all])
#   Using cached optax-0.2.6-py3-none-any.whl.metadata (7.6 kB)
# Collecting orbax-checkpoint (from flax>=0.5.0->gymnasium[all])
#   Using cached orbax_checkpoint-0.11.28-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorstore (from flax>=0.5.0->gymnasium[all])
#   Using cached tensorstore-0.1.79-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: rich>=11.1 in c:\anaconda3\lib\site-packages (from flax>=0.5.0->gymnasium[all]) (13.3.5)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\anaconda3\lib\site-packages (from flax>=0.5.0->gymnasium[all]) (6.0.1)
# Collecting treescope>=0.1.7 (from flax>=0.5.0->gymnasium[all])
#   Using cached treescope-0.1.10-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pillow>=8.3.2 in c:\anaconda3\lib\site-packages (from imageio>=2.14.1->gymnasium[all]) (10.3.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from jax>=0.4.16->gymnasium[all]) (0.5.4)
# Requirement already satisfied: opt_einsum in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from jax>=0.4.16->gymnasium[all]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in c:\anaconda3\lib\site-packages (from jax>=0.4.16->gymnasium[all]) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0->gymnasium[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib>=3.0->gymnasium[all]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (5.1.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[all])
#   Using cached imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[all])
#   Using cached proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: python-dotenv>=0.10 in c:\anaconda3\lib\site-packages (from moviepy>=1.0.0->gymnasium[all]) (0.21.0)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[all]) (4.66.4)
# Requirement already satisfied: absl-py in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from mujoco>=2.1.5->gymnasium[all]) (2.3.1)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[all])
#   Using cached etils-1.13.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Using cached glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-win_amd64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[all])
#   Using cached pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.0)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch>=1.13.0->gymnasium[all]) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch>=1.13.0->gymnasium[all]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch>=1.13.0->gymnasium[all]) (3.2.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch>=1.13.0->gymnasium[all]) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\lib\site-packages (from torch>=1.13.0->gymnasium[all]) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch>=1.13.0->gymnasium[all]) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.13.0->gymnasium[all]) (1.3.0)
# Collecting importlib_resources (from etils[epath]->mujoco>=2.1.5->gymnasium[all])
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp in c:\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch>=1.13.0->gymnasium[all]) (2.1.3)
# Collecting chex>=0.1.87 (from optax->flax>=0.5.0->gymnasium[all])
#   Using cached chex-0.1.91-py3-none-any.whl.metadata (18 kB)
# Collecting toolz>=1.0.0 (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all])
#   Using cached toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: nest_asyncio in c:\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.6.0)
# Collecting aiofiles (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Using cached aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: protobuf in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (6.33.1)
# Collecting humanize (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Using cached humanize-4.14.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting simplejson>=3.16.0 (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Using cached simplejson-3.20.2-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: psutil in c:\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (5.9.0)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm->proglog<=1.0.0->moviepy>=1.0.0->gymnasium[all]) (0.4.6)
# Using cached swig-4.4.0-py3-none-win_amd64.whl (2.5 MB)
# Using cached array_api_compat-1.12.0-py3-none-any.whl (58 kB)
# Using cached flax-0.12.1-py3-none-any.whl (488 kB)
# Using cached jax-0.8.1-py3-none-any.whl (2.9 MB)
# Using cached jaxlib-0.8.1-cp312-cp312-win_amd64.whl (59.8 MB)
# Using cached moviepy-2.2.1-py3-none-any.whl (129 kB)
# Using cached proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl (31.2 MB)
# Using cached mujoco-3.3.7-cp312-cp312-win_amd64.whl (5.4 MB)
# Using cached treescope-0.1.10-py3-none-any.whl (182 kB)
# Using cached etils-1.13.0-py3-none-any.whl (170 kB)
# Using cached glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-win_amd64.whl (559 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached optax-0.2.6-py3-none-any.whl (367 kB)
# Using cached chex-0.1.91-py3-none-any.whl (100 kB)
# Using cached toolz-1.1.0-py3-none-any.whl (58 kB)
# Using cached orbax_checkpoint-0.11.28-py3-none-any.whl (586 kB)
# Using cached simplejson-3.20.2-cp312-cp312-win_amd64.whl (75 kB)
# Using cached tensorstore-0.1.79-cp312-cp312-win_amd64.whl (13.2 MB)
# Using cached aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Using cached humanize-4.14.0-py3-none-any.whl (132 kB)
# Using cached pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (pyproject.toml): started
#   Building wheel for box2d-py (pyproject.toml): finished with status 'error'
# Failed to build box2d-py

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from env.hospital_env import HospitalEnv

# Create environment
env = HospitalEnv()

# Create DQN agent
model = DQN(
    "MlpPolicy",       # Fully connected NN
    env,
    learning_rate=5e-4,
    gamma=0.95,
    batch_size=64,
    buffer_size=50000,
    exploration_fraction=0.1,   # epsilon decay
    exploration_initial_eps=1.0,
    exploration_final_eps=0.1,
    target_update_interval=1000,
    verbose=1
)

# Train agent
model.learn(total_timesteps=50000)

# Save trained model
model.save("../models/dqn_hospital_sb3")
print("Model saved to models/dqn_hospital_sb3.zip")

# Evaluate agent
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 2
#       1 import gymnasium as gym
# ----> 2 from stable_baselines3 import DQN
#       3 from stable_baselines3.common.evaluation import evaluate_policy
#       4 from env.hospital_env import HospitalEnv
#
# File ~\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\__init__.py:3
#       1 import os
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# File ~\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\a2c\__init__.py:1
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       4 __all__ = ["A2C", "CnnPolicy", "MlpPolicy", "MultiInputPolicy"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\stable_baselines3\a2c\a2c.py:3
#       1 from typing import Any, ClassVar, Optional, TypeVar, Union
# ----> 3 import torch as th
#       4 from gymnasium import spaces
#       5 from torch.nn import functional as F
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "C:\Users\Prudence Letaru\AppData\Roaming\Python\Python312\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
# Load trained model
model = DQN.load("../models/dqn_hospital_sb3")

obs, info = env.reset()
done = False
total_reward = 0

for _ in range(50):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    total_reward += reward

print("Total reward after training:", total_reward)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Load trained model
# ----> 2 model = DQN.load("../models/dqn_hospital_sb3")
#       4 obs, info = env.reset()
#       5 done = False
#
# NameError: name 'DQN' is not defined

# %%
! pip uninstall torch torchvision torchaudio -y
! pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Found existing installation: torch 2.9.1
# Uninstalling torch-2.9.1:
#   Successfully uninstalled torch-2.9.1
# Found existing installation: torchvision 0.24.1
# Uninstalling torchvision-0.24.1:
#   Successfully uninstalled torchvision-0.24.1
# Found existing installation: torchaudio 2.9.1
# Uninstalling torchaudio-2.9.1:
#   Successfully uninstalled torchaudio-2.9.1
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.9.1%2Bcpu-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.24.1%2Bcpu-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.9.1%2Bcpu-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: numpy in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.9.1%2Bcpu-cp312-cp312-win_amd64.whl (110.9 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.24.1%2Bcpu-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.9.1%2Bcpu-cp312-cp312-win_amd64.whl (663 kB)
# Installing collected packages: torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.9.1+cpu torchaudio-2.9.1+cpu torchvision-0.24.1+cpu
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\Prudence Letaru\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
! pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (2.9.1+cpu)
# Requirement already satisfied: torchvision in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (0.24.1+cpu)
# Requirement already satisfied: torchaudio in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (2.9.1+cpu)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: numpy in c:\users\prudence letaru\appdata\roaming\python\python312\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
# Using venv
python -m venv rl_env
rl_env\Scripts\activate

# Upgrade pip
python -m pip install --upgrade pip

# Install required packages inside the clean env
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
pip install stable-baselines3 gymnasium numpy pandas matplotlib
# Out:
#   Cell In[20], line 2
#     python -m venv rl_env
#               ^
# SyntaxError: invalid syntax
